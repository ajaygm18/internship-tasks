# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spotify = pd.read_csv("Spotify_data.csv")
spotify['Release Date'] = pd.to_datetime(spotify['Release Date'])
spotify.head(5)
# Out:
#    Unnamed: 0                  Track Name  \
# 0           0                 Not Like Us
# 1           1                     Houdini
# 2           2  BAND4BAND (feat. Lil Baby)
# 3           3          I Don't Wanna Wait
# 4           4                       Pedro
#
#                                    Artists                  Album Name  \
# 0                           Kendrick Lamar                 Not Like Us
# 1                                   Eminem                     Houdini
# 2                    Central Cee, Lil Baby  BAND4BAND (feat. Lil Baby)
# 3                David Guetta, OneRepublic          I Don't Wanna Wait
# 4  Jaxomy, Agatino Romero, Raffaella Carrà                       Pedro
#
#                  Album ID                Track ID  Popularity Release Date  \
# 0  5JjnoGJyOxfSZUZtk2rRwZ  6AI3ezQ4o3HUoP6Dhudph3          96   2024-05-04
# 1  6Xuu2z00jxRPZei4IJ9neK  2HYFX63wP3otVIvopRS99Z          94   2024-05-31
# ...

# %%
spotify.describe()
# Out:
#        Unnamed: 0  Popularity                Release Date  Duration (ms)  \
# count  227.000000   227.00000                         227     227.000000
# mean   113.000000    71.85022  2021-06-24 13:51:00.792951  219254.881057
# min      0.000000    13.00000         2001-10-19 00:00:00   96947.000000
# 25%     56.500000    68.00000         2019-06-14 00:00:00  170554.500000
# 50%    113.000000    72.00000         2022-10-21 00:00:00  222462.000000
# 75%    169.500000    78.00000         2023-12-04 00:00:00  265611.000000
# max    226.000000    96.00000         2024-05-31 00:00:00  383639.000000
# std     65.673435    10.24110                         NaN   60483.492317
#
#        Danceability      Energy         Key    Loudness        Mode  \
# count    227.000000  227.000000  227.000000  227.000000  227.000000
# mean       0.635639    0.646665    5.458150   -6.516670    0.678414
# min        0.271000    0.236000    0.000000  -15.073000    0.000000
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        227 non-null    int64
#  1   Track Name        227 non-null    str
#  2   Artists           227 non-null    str
#  3   Album Name        227 non-null    str
#  4   Album ID          227 non-null    str
#  5   Track ID          227 non-null    str
#  6   Popularity        227 non-null    int64
#  7   Release Date      227 non-null    datetime64[us]
#  8   Duration (ms)     227 non-null    int64
#  9   Explicit          227 non-null    bool
#  10  External URLs     227 non-null    str
#  11  Danceability      227 non-null    float64
#  12  Energy            227 non-null    float64
#  13  Key               227 non-null    int64
#  14  Loudness          227 non-null    float64
#  15  Mode              227 non-null    int64
#  16  Speechiness       227 non-null    float64
# ...

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'Track Name', 'Artists', 'Album Name', 'Album ID',
#        'Track ID', 'Popularity', 'Release Date', 'Duration (ms)', 'Explicit',
#        'External URLs', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo'],
#       dtype='str')

# %%
spotify.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
features = ['Energy', 'Valence', 'Danceability', 'Loudness', 'Acousticness']
features
# Out:
# ['Energy', 'Valence', 'Danceability', 'Loudness', 'Acousticness']

# %%
for feature in features:
    plt.figure(figsize=(8,6))
    sns.scatterplot(data=spotify, x=feature, y='Popularity')
    plt.title(f"Popularity vs {feature}")
    plt.show()

# %%
numeric = spotify.select_dtypes(['int64', 'float64'])
correlation = numeric.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Popularity, Loudness, Danceability, Energy has a +ve correlation 
# Acousticness has -ve correlation

# %%
for feature in features:
    sns.histplot(data=spotify, x=feature, kde=True)
    plt.show()

# %%
# MACHINE LEARNING
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

features = ['Energy', 'Valence', 'Danceability', 'Loudness',
            'Acousticness', 'Tempo', 'Speechiness', 'Liveness']

X = spotify[features]
y = spotify['Popularity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=42)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
param_grid = {
    'n_estimators': [10, 100, 200],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search_rf = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, refit=True, cv=KFold(n_splits=5, shuffle=True, random_state=42), verbose=2)

grid_search_rf.fit(X_train_scaled, y_train)

best_params = grid_search_rf.best_params_

best_rf_model = grid_search_rf.best_estimator_

y_pred_best = best_rf_model.predict(X_test_scaled)

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred_best, alpha=0.7)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
plt.show()
