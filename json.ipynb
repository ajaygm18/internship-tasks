# %%
import json

# %%
sample_dict = {
    'course_name': "Python",
    'fees': 1000
}

# %%
json.dumps(sample_dict)
# Out:
# '{"course_name": "Python", "fees": 1000}'

# %%
jsonstr = '{"course":"Python","fees":18000}'
print(json.loads(jsonstr))
# Out:
# {'course': 'Python', 'fees': 18000}

# %%
from collections import defaultdict

# %%
dct2 = defaultdict()

# %%
dct2['xd'] = 48
dct2.
# Out:
# defaultdict(None, {'xd': 48})
