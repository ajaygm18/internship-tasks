# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
l = [54,234,45-1,43,-1,'val']

# %%
print(l)
# Out:
# [54, 234, 44, 43, -1, 'val']

# %%
sr1 = pd.Series(l)

# %%
sr1
# Out:
# 0     54
# 1    234
# 2     44
# 3     43
# 4     -1
# 5    val
# dtype: object

# %%
type(sr1)
# Out:
# pandas.core.series.Series

# %%
sr2 = pd.Series([432,54,2,52,43,3525,43245])
sr2
# Out:
# 0      432
# 1       54
# 2        2
# 3       52
# 4       43
# 5     3525
# 6    43245
# dtype: int64

# %%
sr3 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432])
sr3
# Out:
# 5         432
# 43         54
# 543         2
# 5434       52
# 1          43
# 53       3525
# 5432    43245
# dtype: int64

# %%
sr3 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432], dtype=float)
sr3
# Out:
# 5         432.0
# 43         54.0
# 543         2.0
# 5434       52.0
# 1          43.0
# 53       3525.0
# 5432    43245.0
# dtype: float64

# %%
sr4 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432], dtype=float, name="Data Values")
sr4
# Out:
# 5         432.0
# 43         54.0
# 543         2.0
# 5434       52.0
# 1          43.0
# 53       3525.0
# 5432    43245.0
# Name: Data Values, dtype: float64

# %%
scaler_s = pd.Series(0.5)
scaler_s
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s = pd.Series(0.5, index=[1,2,3])
scaler_s
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
scaler_s = pd.Series({'a': 12, 'b': 16, 'c': 18})
scaler_s
# Out:
# a    12
# b    16
# c    18
# dtype: int64

# %%
scaler_s['a']
# Out:
# np.int64(12)

# %%
scaler_s.iloc[0]
# Out:
# np.int64(12)

# %%
scaler_s.iloc[1:4]
# Out:
# b    16
# c    18
# dtype: int64

# %%
max(scaler_s)
# Out:
# 18

# %%
min(scaler_s)
# Out:
# 12

# %%
scaler_s[scaler_s > 1]
# Out:
# a    12
# b    16
# c    18
# dtype: int64

# %%
s5 = pd.Series([1,2,3,4,5])
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4 = pd.Series([4,5,4,3,3])
s5 + s4
# Out:
# 0    5
# 1    7
# 2    7
# 3    7
# 4    8
# dtype: int64

# %%
pd.Series([4,6,2]) + s5
# Out:
# 0    5.0
# 1    8.0
# 2    5.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['a', 'b', 'c']
lst
# Out:
# ['a', 'b', 'c']

# %%
df1 = pd.DataFrame(lst)

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls_of_ls = [[1,2,3], [4,5,6], [7,8,9]]
ls_of_ls
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df2 = pd.DataFrame(ls_of_ls)

# %%
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dct = {
    '1D': [12,314,234,53,4]
}
df3 = pd.DataFrame(dct)

# %%
df3
# Out:
#     1D
# 0   12
# 1  314
# 2  234
# 3   53
# 4    4

# %%
dct1 = {
    '1D': [12,314,234,53,4],
    'XD': [12,34,234,53,4]
}
df4 = pd.DataFrame(dct1)

# %%
df4
# Out:
#     1D   XD
# 0   12   12
# 1  314   34
# 2  234  234
# 3   53   53
# 4    4    4

# %%
dct2 = [{'a': 1, 'b': 2}, {'a': 4, 'b': 8}]

# %%
dct2
# Out:
# [{'a': 1, 'b': 2}, {'a': 4, 'b': 8}]

# %%
df5 = pd.DataFrame(dct2)
df5
# Out:
#    a  b
# 0  1  2
# 1  4  8

# %%
dct3 = [{'a': 1, 'b': 2}, {'a': 4, 'b': 8, 'c': 1}]
pd.DataFrame(dct3)
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  4  8  1.0

# %%
dict_sr = [pd.Series([1,2,3]), pd.Series([4,5,6])]
dict_sr
# Out:
# [0    1
#  1    2
#  2    3
#  dtype: int64,
#  0    4
#  1    5
#  2    6
#  dtype: int64]

# %%
pd.DataFrame(dict_sr)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
pd.read_csv('data.csv')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ajaya'

# %%
data = pd.read_csv('data.csv')

# %%
data.head(5)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
d1 = pd.read_csv('data.csv', nrows=5)
d1
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
pd.read_csv('data.csv', usecols=['Date', 'Calories'], nrows=5)
# Out:
#            Date  Calories
# 0  '2020/12/01'     409.1
# 1  '2020/12/02'     479.0
# 2  '2020/12/03'     340.0
# 3  '2020/12/04'     282.4
# 4  '2020/12/05'     406.0

# %%
pd.read_csv('data.csv', usecols=[2,3], nrows=5)
# Out:
#    Pulse  Maxpulse
# 0    110       130
# 1    117       145
# 2    103       135
# 3    109       175
# 4    117       148

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=1)
# Out:
#    60  '2020/12/01'  110  130  409.1
# 0  60  '2020/12/02'  117  145  479.0
# 1  60  '2020/12/03'  103  135  340.0
# 2  45  '2020/12/04'  109  175  282.4
# 3  45  '2020/12/05'  117  148  406.0
# 4  60  '2020/12/06'  102  127  300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=2)
# Out:
#    60  '2020/12/02'  117  145  479.0
# 0  60  '2020/12/03'  103  135  340.0
# 1  45  '2020/12/04'  109  175  282.4
# 2  45  '2020/12/05'  117  148  406.0
# 3  60  '2020/12/06'  102  127  300.0
# 4  60  '2020/12/07'  110  136  374.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[0,2])
# Out:
#    60  '2020/12/01'  110  130  409.1
# 0  60  '2020/12/03'  103  135  340.0
# 1  45  '2020/12/04'  109  175  282.4
# 2  45  '2020/12/05'  117  148  406.0
# 3  60  '2020/12/06'  102  127  300.0
# 4  60  '2020/12/07'  110  136  374.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5])
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        60  '2020/12/06'    102       127     300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5], index_col='Date')
# Out:
#               Duration  Pulse  Maxpulse  Calories
# Date
# '2020/12/01'        60    110       130     409.1
# '2020/12/02'        60    117       145     479.0
# '2020/12/03'        60    103       135     340.0
# '2020/12/04'        45    109       175     282.4
# '2020/12/06'        60    102       127     300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5], index_col=3)
# Out:
#           Duration          Date  Pulse  Calories
# Maxpulse
# 130             60  '2020/12/01'    110     409.1
# 145             60  '2020/12/02'    117     479.0
# 135             60  '2020/12/03'    103     340.0
# 175             45  '2020/12/04'    109     282.4
# 127             60  '2020/12/06'    102     300.0
