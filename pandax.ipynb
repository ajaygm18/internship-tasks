# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
l = [54,234,45-1,43,-1,'val']

# %%
print(l)
# Out:
# [54, 234, 44, 43, -1, 'val']

# %%
sr1 = pd.Series(l)

# %%
sr1
# Out:
# 0     54
# 1    234
# 2     44
# 3     43
# 4     -1
# 5    val
# dtype: object

# %%
type(sr1)
# Out:
# pandas.core.series.Series

# %%
sr2 = pd.Series([432,54,2,52,43,3525,43245])
sr2
# Out:
# 0      432
# 1       54
# 2        2
# 3       52
# 4       43
# 5     3525
# 6    43245
# dtype: int64

# %%
sr3 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432])
sr3
# Out:
# 5         432
# 43         54
# 543         2
# 5434       52
# 1          43
# 53       3525
# 5432    43245
# dtype: int64

# %%
sr3 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432], dtype=float)
sr3
# Out:
# 5         432.0
# 43         54.0
# 543         2.0
# 5434       52.0
# 1          43.0
# 53       3525.0
# 5432    43245.0
# dtype: float64

# %%
sr4 = pd.Series([432,54,2,52,43,3525,43245], index=[5,43,543,5434,1,53,5432], dtype=float, name="Data Values")
sr4
# Out:
# 5         432.0
# 43         54.0
# 543         2.0
# 5434       52.0
# 1          43.0
# 53       3525.0
# 5432    43245.0
# Name: Data Values, dtype: float64

# %%
scaler_s = pd.Series(0.5)
scaler_s
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s = pd.Series(0.5, index=[1,2,3])
scaler_s
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
scaler_s = pd.Series({'a': 12, 'b': 16, 'c': 18})
scaler_s
# Out:
# a    12
# b    16
# c    18
# dtype: int64

# %%
scaler_s['a']
# Out:
# np.int64(12)

# %%
scaler_s.iloc[0]
# Out:
# np.int64(12)

# %%
scaler_s.iloc[1:4]
# Out:
# b    16
# c    18
# dtype: int64

# %%
max(scaler_s)
# Out:
# 18

# %%
min(scaler_s)
# Out:
# 12

# %%
scaler_s[scaler_s > 1]
# Out:
# a    12
# b    16
# c    18
# dtype: int64

# %%
s5 = pd.Series([1,2,3,4,5])
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4 = pd.Series([4,5,4,3,3])
s5 + s4
# Out:
# 0    5
# 1    7
# 2    7
# 3    7
# 4    8
# dtype: int64

# %%
pd.Series([4,6,2]) + s5
# Out:
# 0    5.0
# 1    8.0
# 2    5.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['a', 'b', 'c']
lst
# Out:
# ['a', 'b', 'c']

# %%
df1 = pd.DataFrame(lst)

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls_of_ls = [[1,2,3], [4,5,6], [7,8,9]]
ls_of_ls
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df2 = pd.DataFrame(ls_of_ls)

# %%
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dct = {
    '1D': [12,314,234,53,4]
}
df3 = pd.DataFrame(dct)

# %%
df3
# Out:
#     1D
# 0   12
# 1  314
# 2  234
# 3   53
# 4    4

# %%
dct1 = {
    '1D': [12,314,234,53,4],
    'XD': [12,34,234,53,4]
}
df4 = pd.DataFrame(dct1)

# %%
df4
# Out:
#     1D   XD
# 0   12   12
# 1  314   34
# 2  234  234
# 3   53   53
# 4    4    4

# %%
dct2 = [{'a': 1, 'b': 2}, {'a': 4, 'b': 8}]

# %%
dct2
# Out:
# [{'a': 1, 'b': 2}, {'a': 4, 'b': 8}]

# %%
df5 = pd.DataFrame(dct2)
df5
# Out:
#    a  b
# 0  1  2
# 1  4  8

# %%
dct3 = [{'a': 1, 'b': 2}, {'a': 4, 'b': 8, 'c': 1}]
pd.DataFrame(dct3)
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  4  8  1.0

# %%
dict_sr = [pd.Series([1,2,3]), pd.Series([4,5,6])]
dict_sr
# Out:
# [0    1
#  1    2
#  2    3
#  dtype: int64,
#  0    4
#  1    5
#  2    6
#  dtype: int64]

# %%
pd.DataFrame(dict_sr)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
pd.read_csv('data.csv')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ajaya'

# %%
data = pd.read_csv('data.csv')

# %%
data.head(5)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
d1 = pd.read_csv('data.csv', nrows=5)
d1
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
pd.read_csv('data.csv', usecols=['Date', 'Calories'], nrows=5)
# Out:
#            Date  Calories
# 0  '2020/12/01'     409.1
# 1  '2020/12/02'     479.0
# 2  '2020/12/03'     340.0
# 3  '2020/12/04'     282.4
# 4  '2020/12/05'     406.0

# %%
pd.read_csv('data.csv', usecols=[2,3], nrows=5)
# Out:
#    Pulse  Maxpulse
# 0    110       130
# 1    117       145
# 2    103       135
# 3    109       175
# 4    117       148

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=1)
# Out:
#    60  '2020/12/01'  110  130  409.1
# 0  60  '2020/12/02'  117  145  479.0
# 1  60  '2020/12/03'  103  135  340.0
# 2  45  '2020/12/04'  109  175  282.4
# 3  45  '2020/12/05'  117  148  406.0
# 4  60  '2020/12/06'  102  127  300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=2)
# Out:
#    60  '2020/12/02'  117  145  479.0
# 0  60  '2020/12/03'  103  135  340.0
# 1  45  '2020/12/04'  109  175  282.4
# 2  45  '2020/12/05'  117  148  406.0
# 3  60  '2020/12/06'  102  127  300.0
# 4  60  '2020/12/07'  110  136  374.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[0,2])
# Out:
#    60  '2020/12/01'  110  130  409.1
# 0  60  '2020/12/03'  103  135  340.0
# 1  45  '2020/12/04'  109  175  282.4
# 2  45  '2020/12/05'  117  148  406.0
# 3  60  '2020/12/06'  102  127  300.0
# 4  60  '2020/12/07'  110  136  374.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5])
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        60  '2020/12/06'    102       127     300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5], index_col='Date')
# Out:
#               Duration  Pulse  Maxpulse  Calories
# Date
# '2020/12/01'        60    110       130     409.1
# '2020/12/02'        60    117       145     479.0
# '2020/12/03'        60    103       135     340.0
# '2020/12/04'        45    109       175     282.4
# '2020/12/06'        60    102       127     300.0

# %%
pd.read_csv('data.csv',  nrows=5, skiprows=[5], index_col=3)
# Out:
#           Duration          Date  Pulse  Calories
# Maxpulse
# 130             60  '2020/12/01'    110     409.1
# 145             60  '2020/12/02'    117     479.0
# 135             60  '2020/12/03'    103     340.0
# 175             45  '2020/12/04'    109     282.4
# 127             60  '2020/12/06'    102     300.0

# %%
pd.read_csv('data.csv', header=0, nrows=5)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
pd.read_csv('data.csv', header=None, nrows=5)
# Out:
#           0             1      2         3         4
# 0  Duration          Date  Pulse  Maxpulse  Calories
# 1        60  '2020/12/01'    110       130     409.1
# 2        60  '2020/12/02'    117       145     479.0
# 3        60  '2020/12/03'    103       135     340.0
# 4        45  '2020/12/04'    109       175     282.4

# %%
df2 = pd.read_csv('data.csv', header=None, nrows=5)

# %%
df2.columns = [f"xd{i}" for i in range(len(df2.columns))]

# %%
df2
# Out:
#         xd0           xd1    xd2       xd3       xd4
# 0  Duration          Date  Pulse  Maxpulse  Calories
# 1        60  '2020/12/01'    110       130     409.1
# 2        60  '2020/12/02'    117       145     479.0
# 3        60  '2020/12/03'    103       135     340.0
# 4        45  '2020/12/04'    109       175     282.4

# %%
df2 = pd.read_csv('data.csv', names=[i**2 for i in range(5)], nrows=5)
df2
# Out:
#          0             1      4         9         16
# 0  Duration          Date  Pulse  Maxpulse  Calories
# 1        60  '2020/12/01'    110       130     409.1
# 2        60  '2020/12/02'    117       145     479.0
# 3        60  '2020/12/03'    103       135     340.0
# 4        45  '2020/12/04'    109       175     282.4

# %%
df2 = pd.read_csv('data.csv', nrows=5, dtype={'Duration': 'float64'})
df2
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0      60.0  '2020/12/01'    110       130     409.1
# 1      60.0  '2020/12/02'    117       145     479.0
# 2      60.0  '2020/12/03'    103       135     340.0
# 3      45.0  '2020/12/04'    109       175     282.4
# 4      45.0  '2020/12/05'    117       148     406.0

# %%
df2['Random'] = pd.Series(['Yes' for i in range(len(df2))])
df2.loc[5:10, 'Random'] = "No"

# %%
df2.to_csv('data2.csv', index=False)

# %%
df3 = pd.read_csv('data2.csv', true_values=['Yes'], false_values=['No'])
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0      60.0  '2020/12/01'    110       130     409.1    True
# 1      60.0  '2020/12/02'    117       145     479.0    True
# 2      60.0  '2020/12/03'    103       135     340.0    True
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3 = pd.read_csv('data2.csv', true_values=['Yes'], false_values=['No'], na_values=['No'])
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0      60.0  '2020/12/01'    110       130     409.1    True
# 1      60.0  '2020/12/02'    117       145     479.0    True
# 2      60.0  '2020/12/03'    103       135     340.0    True
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3 = pd.read_csv('data2.csv', true_values=['Yes'], false_values=['No'], na_values={'Random': 'No', 'Duration': 60}, nrows=25)
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# 1       NaN  '2020/12/02'    117       145     479.0    True
# 2       NaN  '2020/12/03'    103       135     340.0    True
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3 = pd.read_csv('data2.csv', true_values=['Yes'], false_values=['No'], na_values={'Random': 'No', 'Duration': 60}, nrows=25, na_filter=True)
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# 1       NaN  '2020/12/02'    117       145     479.0    True
# 2       NaN  '2020/12/03'    103       135     340.0    True
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.isnull()
# Out:
#    Duration   Date  Pulse  Maxpulse  Calories  Random
# 0      True  False  False     False     False   False
# 1      True  False  False     False     False   False
# 2      True  False  False     False     False   False
# 3     False  False  False     False     False   False
# 4     False  False  False     False     False   False

# %%
df3.isnull().sum()
# Out:
# Duration    3
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# Random      0
# dtype: int64

# %%
df3.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
df3.isnull().sum()
# Out:
# Duration    3
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# Random      0
# dtype: int64

# %%
df3.notnull()
# Out:
#    Duration  Date  Pulse  Maxpulse  Calories  Random
# 0     False  True   True      True      True    True
# 1     False  True   True      True      True    True
# 2     False  True   True      True      True    True
# 3      True  True   True      True      True    True
# 4      True  True   True      True      True    True

# %%
df3.notnull().sum()
# Out:
# Duration    2
# Date        5
# Pulse       5
# Maxpulse    5
# Calories    5
# Random      5
# dtype: int64

# %%
df3.notnull().sum().sum()
# Out:
# np.int64(27)

# %%
df4 = pd.Series([4,2,5,7,4,2,np.nan])

# %%
df4.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df4.dropna()
# Out:
# 0    4.0
# 1    2.0
# 2    5.0
# 3    7.0
# 4    4.0
# 5    2.0
# dtype: float64

# %%
df4.dropna(axis=0)
# Out:
# 0    4.0
# 1    2.0
# 2    5.0
# 3    7.0
# 4    4.0
# 5    2.0
# dtype: float64

# %%
df3.dropna(axis=1)
# Out:
#            Date  Pulse  Maxpulse  Calories  Random
# 0  '2020/12/01'    110       130     409.1    True
# 1  '2020/12/02'    117       145     479.0    True
# 2  '2020/12/03'    103       135     340.0    True
# 3  '2020/12/04'    109       175     282.4    True
# 4  '2020/12/05'    117       148     406.0    True

# %%
df3.dropna(how='all')
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# 1       NaN  '2020/12/02'    117       145     479.0    True
# 2       NaN  '2020/12/03'    103       135     340.0    True
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.dropna(how='any')
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.dropna(thresh=6)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.dropna(subset=['Duration'])
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.fillna(0)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.fillna({'Duration': 999, 'Random': 'XD'})
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.ffill().bfill()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.fillna(method='pad')
# Out:
# C:\Users\ajaya\AppData\Local\Temp\ipykernel_4652\2392179455.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3.fillna(method='pad')
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.bfill(axis=1)
# Out:
#   Duration          Date Pulse Maxpulse Calories Random
# 3     45.0  '2020/12/04'   109      175    282.4   True
# 4     45.0  '2020/12/05'   117      148    406.0   True

# %%
df3.replace(True, "xd")
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories Random
# 3      45.0  '2020/12/04'    109       175     282.4     xd
# 4      45.0  '2020/12/05'    117       148     406.0     xd

# %%
df3.replace([130,135], [99,999])
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.replace({'Duration': np.nan, 'Calories': np.nan}, None)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.replace('\d\d\d', 700, regex=True)
# Out:
# C:\Users\ajaya\AppData\Local\Temp\ipykernel_4652\2479844212.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3.replace('\d\d\d', 700, regex=True)
#    Duration  Date  Pulse  Maxpulse  Calories  Random
# 3      45.0   700    109       175     282.4    True
# 4      45.0   700    117       148     406.0    True

# %%
df3['Calories'].astype(str)
df3.replace({'Calories': '^\d{3}\.\d'}, None, regex=True)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.replace(True, "Lol", inplace=True)

# %%
df3
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories Random
# 3      45.0  '2020/12/04'    109       175     282.4    Lol
# 4      45.0  '2020/12/05'    117       148     406.0    Lol

# %%
df3.interpolate()
# Out:
# C:\Users\ajaya\AppData\Local\Temp\ipykernel_4652\1273901375.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df3.interpolate()
#    Duration          Date  Pulse  Maxpulse  Calories Random
# 3      45.0  '2020/12/04'    109       175     282.4    Lol
# 4      45.0  '2020/12/05'    117       148     406.0    Lol

# %%
df3['Duration']
# Out:
# 3    45.0
# 4    45.0
# Name: Duration, dtype: float64

# %%
df3.loc[4]
# Out:
# Duration            45.0
# Date        '2020/12/05'
# Pulse                117
# Maxpulse             148
# Calories           406.0
# Random               Lol
# Name: 4, dtype: object

# %%
df3.loc[4, 'Duration']
# Out:
# np.float64(45.0)

# %%
df3.loc[4:8, 'Duration']
# Out:
# 4    45.0
# Name: Duration, dtype: float64

# %%
df3.loc[[0,1,4]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# 1       NaN  '2020/12/02'    117       145     479.0    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.loc[[0,1,4], 'Duration']
# Out:
# 0     NaN
# 1     NaN
# 4    45.0
# Name: Duration, dtype: float64

# %%
df3.loc[[False, False, False, True, True]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3.loc[df3['Pulse'] > 109, ['Date', 'Random']]
# Out:
#            Date  Random
# 0  '2020/12/01'    True
# 1  '2020/12/02'    True
# 4  '2020/12/05'    True

# %%
df3.iloc[0]
# Out:
# Duration             NaN
# Date        '2020/12/01'
# Pulse                110
# Maxpulse             130
# Calories           409.1
# Random              True
# Name: 0, dtype: object

# %%
df3.iloc[[0]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True

# %%
df3[['Duration']]
# Out:
#    Duration
# 0       NaN
# 1       NaN
# 2       NaN
# 3      45.0
# 4      45.0

# %%
df3.loc[:, 'Pulse']
# Out:
# 0    110
# 1    117
# 2    103
# 3    109
# 4    117
# Name: Pulse, dtype: int64

# %%
df3.iloc[:, 'Pulse']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 1
# ...

# %%
df3.iloc[[0, 1]]
# Out:
# 0    110
# 1    117
# Name: Pulse, dtype: int64

# %%
df3.iloc[[True, True, False, False, True]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# 1       NaN  '2020/12/02'    117       145     479.0    True
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
df3p = df3.groupby(by='Maxpulse')
df3p.groups
# Out:
# {130: [0], 135: [2], 145: [1], 148: [4], 175: [3]}

# %%
df4p = df3.groupby(['Date', 'Maxpulse'])

# %%
df4p.groups
# Out:
# {(''2020/12/01'', 130): [0], (''2020/12/02'', 145): [1], (''2020/12/03'', 135): [2], (''2020/12/04'', 175): [3], (''2020/12/05'', 148): [4]}

# %%
for section, x in df4p:
    print(section)
    print(x)
# Out:
# ("'2020/12/01'", np.int64(130))
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 0       NaN  '2020/12/01'    110       130     409.1    True
# ("'2020/12/02'", np.int64(145))
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 1       NaN  '2020/12/02'    117       145     479.0    True
# ("'2020/12/03'", np.int64(135))
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 2       NaN  '2020/12/03'    103       135     340.0    True
# ("'2020/12/04'", np.int64(175))
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 3      45.0  '2020/12/04'    109       175     282.4    True
# ("'2020/12/05'", np.int64(148))
#    Duration          Date  Pulse  Maxpulse  Calories  Random
# 4      45.0  '2020/12/05'    117       148     406.0    True

# %%
list(df3p)
# Out:
# [(130,
#      Duration          Date  Pulse  Maxpulse  Calories  Random
#   0       NaN  '2020/12/01'    110       130     409.1    True),
#  (135,
#      Duration          Date  Pulse  Maxpulse  Calories  Random
#   2       NaN  '2020/12/03'    103       135     340.0    True),
#  (145,
#      Duration          Date  Pulse  Maxpulse  Calories  Random
#   1       NaN  '2020/12/02'    117       145     479.0    True),
#  (148,
#      Duration          Date  Pulse  Maxpulse  Calories  Random
#   4      45.0  '2020/12/05'    117       148     406.0    True),
#  (175,
#      Duration          Date  Pulse  Maxpulse  Calories  Random
#   3      45.0  '2020/12/04'    109       175     282.4    True)]

# %%
dict(list(df4p))
# Out:
# {("'2020/12/01'",
#   np.int64(130)):    Duration          Date  Pulse  Maxpulse  Calories  Random
#  0       NaN  '2020/12/01'    110       130     409.1    True,
#  ("'2020/12/02'",
#   np.int64(145)):    Duration          Date  Pulse  Maxpulse  Calories  Random
#  1       NaN  '2020/12/02'    117       145     479.0    True,
#  ("'2020/12/03'",
#   np.int64(135)):    Duration          Date  Pulse  Maxpulse  Calories  Random
#  2       NaN  '2020/12/03'    103       135     340.0    True,
#  ("'2020/12/04'",
#   np.int64(175)):    Duration          Date  Pulse  Maxpulse  Calories  Random
#  3      45.0  '2020/12/04'    109       175     282.4    True,
#  ("'2020/12/05'",
#   np.int64(148)):    Duration          Date  Pulse  Maxpulse  Calories  Random
#  4      45.0  '2020/12/05'    117       148     406.0    True}

# %%
 df4g = df3.groupby('Pulse').get_group(117)

# %%
df4g.sum()
# Out:
# Duration                        45.0
# Date        '2020/12/02''2020/12/05'
# Pulse                            234
# Maxpulse                         293
# Calories                       885.0
# Random                             2
# dtype: object

# %%
df4g.drop(['Duration', 'Random', 'Date'], axis=1).mean()
# Out:
# Pulse       117.0
# Maxpulse    146.5
# Calories    442.5
# dtype: float64

# %%
df4g.describe()
# Out:
#        Duration  Pulse   Maxpulse    Calories
# count       1.0    2.0    2.00000    2.000000
# mean       45.0  117.0  146.50000  442.500000
# std         NaN    0.0    2.12132   51.618795
# min        45.0  117.0  145.00000  406.000000
# 25%        45.0  117.0  145.75000  424.250000
# 50%        45.0  117.0  146.50000  442.500000
# 75%        45.0  117.0  147.25000  460.750000
# max        45.0  117.0  148.00000  479.000000

# %%
df4g.drop(['Duration', 'Random', 'Date'], axis=1).agg(['sum', 'max', 'mean'])
# Out:
#       Pulse  Maxpulse  Calories
# sum   234.0     293.0     885.0
# max   117.0     148.0     479.0
# mean  117.0     146.5     442.5

# %%
df = pd.DataFrame({'ID': [1,2,3,4,5], 'Name': ["Ajay", 'Ajay2', "Name", "Nein", "Heil H1tle4"]})
df
# Out:
#    ID         Name
# 0   1         Ajay
# 1   2        Ajay2
# 2   3         Name
# 3   4         Nein
# 4   5  Heil H1tle4

# %%
list(df.groupby(by='Name'))
# Out:
# [('Ajay',
#      ID  Name
#   0   1  Ajay),
#  ('Ajay2',
#      ID   Name
#   1   2  Ajay2),
#  ('Heil H1tle4',
#      ID         Name
#   4   5  Heil H1tle4),
#  ('Name',
#      ID  Name
#   2   3  Name),
#  ('Nein',
#      ID  Name
#   3   4  Nein)]

# %%
df2 = pd.DataFrame({'ID': [1,2,3,4,5], 'Name': ["Ajay", 'Ajay2', "Name", "Nein", "Heil H1tle4x"]})
df2
# Out:
#    ID          Name
# 0   1          Ajay
# 1   2         Ajay2
# 2   3          Name
# 3   4          Nein
# 4   5  Heil H1tle4x

# %%
pd.merge(df, df2)
# Out:
#    ID   Name
# 0   1   Ajay
# 1   2  Ajay2
# 2   3   Name
# 3   4   Nein

# %%
pd.merge(df, df2, on='ID')
# Out:
#    ID       Name_x        Name_y
# 0   1         Ajay          Ajay
# 1   2        Ajay2         Ajay2
# 2   3         Name          Name
# 3   4         Nein          Nein
# 4   5  Heil H1tle4  Heil H1tle4x

# %%
pd.merge(df, df2, on='Name')
# Out:
#    ID_x   Name  ID_y
# 0     1   Ajay     1
# 1     2  Ajay2     2
# 2     3   Name     3
# 3     4   Nein     4

# %%
pd.merge(df, df2, on='Name', how='left')
# Out:
#    ID_x         Name  ID_y
# 0     1         Ajay   1.0
# 1     2        Ajay2   2.0
# 2     3         Name   3.0
# 3     4         Nein   4.0
# 4     5  Heil H1tle4   NaN

# %%
pd.merge(df, df2, on='Name', how='right')
# Out:
#    ID_x          Name  ID_y
# 0   1.0          Ajay     1
# 1   2.0         Ajay2     2
# 2   3.0          Name     3
# 3   4.0          Nein     4
# 4   NaN  Heil H1tle4x     5

# %%
pd.merge(df, df2, how='outer', indicator=True)
# Out:
#    ID          Name      _merge
# 0   1          Ajay        both
# 1   2         Ajay2        both
# 2   3          Name        both
# 3   4          Nein        both
# 4   5   Heil H1tle4   left_only
# 5   5  Heil H1tle4x  right_only

# %%
pd.merge(df, df2, how='outer', indicator=True, left_index=True, right_index=True)
# Out:
#    ID_x       Name_x  ID_y        Name_y _merge
# 0     1         Ajay     1          Ajay   both
# 1     2        Ajay2     2         Ajay2   both
# 2     3         Name     3          Name   both
# 3     4         Nein     4          Nein   both
# 4     5  Heil H1tle4     5  Heil H1tle4x   both

# %%
pd_dict = {
    'Name': ['Ajay', 'Xajay', 'BTCUSD', 'ETHUSD'],
    'Age': [18,81,23,42]
}
df = pd.DataFrame(
    pd_dict,
    index=['Emp1', 'Emp2', 'Emp3', 'Emp4']
)

# %%
df1 = pd.DataFrame([{'Name': 'RTX', 'Age': 99}], index=['Emp5'])

# %%
pd.concat([df, df1])
# Out:
#         Name  Age
# Emp1    Ajay   18
# Emp2   Xajay   81
# Emp3  BTCUSD   23
# Emp4  ETHUSD   42
# Emp5     RTX   99

# %%
df2 = pd.read_csv('dat.csv', index_col='Name')
df2
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
print(df2.to_string())
# Out:
#            Name     Type1     Type2  Height  Weight  Legendary
# No
# 1     Bulbasaur     Grass    Poison     0.7     6.9          0
# 2       Ivysaur     Grass    Poison     1.0    13.0          0
# 3      Venusaur     Grass    Poison     2.0   100.0          0
# 4    Charmander      Fire       NaN     0.6     8.5          0
# 5    Charmeleon      Fire       NaN     1.1    19.0          0
# 6     Charizard      Fire    Flying     1.7    90.5          0
# 7      Squirtle     Water       NaN     0.5     9.0          0
# 8     Wartortle     Water       NaN     1.0    22.5          0
# 9     Blastoise     Water       NaN     1.6    85.5          0
# 10     Caterpie       Bug       NaN     0.3     2.9          0
# 11      Metapod       Bug       NaN     0.7     9.9          0
# 12   Butterfree       Bug    Flying     1.1    32.0          0
# 13       Weedle       Bug    Poison     0.3     3.2          0
# 14       Kakuna       Bug    Poison     0.6    10.0          0
# ...

# %%
df2.loc[['Bulbasaur']]
# Out:
#            No  Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur   1  Grass  Poison     0.7     6.9          0

# %%
df2.iloc[3:7, 1:3]
# Out:
#             Type1   Type2
# Name
# Charmander   Fire     NaN
# Charmeleon   Fire     NaN
# Charizard    Fire  Flying
# Squirtle    Water     NaN

# %%
df2.loc[df2['Weight'] > 50]
# Out:
#              No     Type1     Type2  Height  Weight  Legendary
# Name
# Venusaur      3     Grass    Poison     2.0   100.0          0
# Charizard     6      Fire    Flying     1.7    90.5          0
# Blastoise     9     Water       NaN     1.6    85.5          0
# Arbok        24    Poison       NaN     3.5    65.0          0
# Nidoqueen    31    Poison    Ground     1.3    60.0          0
# Nidoking     34    Poison    Ground     1.4    62.0          0
# Golbat       42    Poison    Flying     1.6    55.0          0
# Golduck      55     Water       NaN     1.7    76.6          0
# Arcanine     59      Fire       NaN     1.9   155.0          0
# Poliwrath    62     Water  Fighting     1.3    54.0          0
# Kadabra      64   Psychic       NaN     1.3    56.5          0
# Machoke      67  Fighting       NaN     1.5    70.5          0
# Machamp      68  Fighting       NaN     1.6   130.0          0
# Tentacruel   73     Water    Poison     1.6    55.0          0
# ...

# %%
df2.loc[df2['Type1'] == 'Poison']
# Out:
#             No   Type1   Type2  Height  Weight  Legendary
# Name
# Ekans       23  Poison     NaN     2.0     6.9          0
# Arbok       24  Poison     NaN     3.5    65.0          0
# Nidoran♀    29  Poison     NaN     0.4     7.0          0
# Nidorina    30  Poison     NaN     0.8    20.0          0
# Nidoqueen   31  Poison  Ground     1.3    60.0          0
# Nidoran♂    32  Poison     NaN     0.5     9.0          0
# Nidorino    33  Poison     NaN     0.9    19.5          0
# Nidoking    34  Poison  Ground     1.4    62.0          0
# Zubat       41  Poison  Flying     0.8     7.5          0
# Golbat      42  Poison  Flying     1.6    55.0          0
# Grimer      88  Poison     NaN     0.9    30.0          0
# Muk         89  Poison     NaN     1.2    30.0          0
# Koffing    109  Poison     NaN     0.6     1.0          0
# Weezing    110  Poison     NaN     1.2     9.5          0

# %%
df2.loc[(df2['Type1'] == 'Poison') & (df2['Type2'].notnull())]
# Out:
#            No   Type1   Type2  Height  Weight  Legendary
# Name
# Nidoqueen  31  Poison  Ground     1.3    60.0          0
# Nidoking   34  Poison  Ground     1.4    62.0          0
# Zubat      41  Poison  Flying     0.8     7.5          0
# Golbat     42  Poison  Flying     1.6    55.0          0

# %%
df2.loc[(df2['Type1'] == 'Poison') | (df2['Type2'].notnull())]
# Out:
#              No     Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1     Grass  Poison     0.7     6.9          0
# Ivysaur       2     Grass  Poison     1.0    13.0          0
# Venusaur      3     Grass  Poison     2.0   100.0          0
# Charizard     6      Fire  Flying     1.7    90.5          0
# Butterfree   12       Bug  Flying     1.1    32.0          0
# ...         ...       ...     ...     ...     ...        ...
# Aerodactyl  142      Rock  Flying     1.8    59.0          0
# Articuno    144       Ice  Flying     1.7    55.4          1
# Zapdos      145  Electric  Flying     1.6    52.6          1
# Moltres     146      Fire  Flying     2.0    60.0          1
# Dragonite   149    Dragon  Flying     2.2   210.0          0
#
# [77 rows x 6 columns]

# %%
df2.mean(numeric_only=True)
# Out:
# No           75.500000
# Height        1.200000
# Weight       46.231333
# Legendary     0.026667
# dtype: float64

# %%
df2.sum(numeric_only=True).sum()
# Out:
# np.float64(18443.7)

# %%
df2.min(numeric_only=True)
# Out:
# No           1.0
# Height       0.2
# Weight       0.1
# Legendary    0.0
# dtype: float64

# %%
df2.max(numeric_only=True)
# Out:
# No           150.0
# Height         8.8
# Weight       460.0
# Legendary      1.0
# dtype: float64

# %%
df2.count()
# Out:
# No           150
# Type1        150
# Type2         67
# Height       150
# Weight       150
# Legendary    150
# dtype: int64

# %%
df2['Height'].mean()
# Out:
# np.float64(1.2)

# %%
df2['Weight'].mean()
# Out:
# np.float64(46.23133333333334)

# %%
dict(list(df2.groupby('Type1')))
# Out:
# {'Bug':              No Type1   Type2  Height  Weight  Legendary
#  Name
#  Caterpie     10   Bug     NaN     0.3     2.9          0
#  Metapod      11   Bug     NaN     0.7     9.9          0
#  Butterfree   12   Bug  Flying     1.1    32.0          0
#  Weedle       13   Bug  Poison     0.3     3.2          0
#  Kakuna       14   Bug  Poison     0.6    10.0          0
#  Beedrill     15   Bug  Poison     1.0    29.5          0
#  Paras        46   Bug   Grass     0.3     5.4          0
#  Parasect     47   Bug   Grass     1.0    29.5          0
#  Venonat      48   Bug  Poison     1.0    30.0          0
#  Venomoth     49   Bug  Poison     1.5    12.5          0
#  Scyther     123   Bug  Flying     1.5    56.0          0
#  Pinsir      127   Bug     NaN     1.5    55.0          0,
#  'Dragon':             No   Type1   Type2  Height  Weight  Legendary
#  Name
#  Dratini    147  Dragon     NaN     1.8     3.3          0
#  Dragonair  148  Dragon     NaN     4.0    16.5          0
# ...

# %%
print(df2.groupby('Type1')['Height'].mean())
# Out:
# Type1
# Bug         0.900000
# Dragon      2.666667
# Electric    0.855556
# Fairy       0.950000
# Fighting    1.185714
# Fire        1.216667
# Ghost       1.466667
# Grass       1.083333
# Ground      0.850000
# Ice         1.550000
# Normal      0.986364
# Poison      1.221429
# Psychic     1.371429
# Rock        1.844444
# Water       1.300000
# Name: Height, dtype: float64

# %%
df2.groupby('Type1')['Height'].mean()
# Out:
# Type1
# Bug         0.900000
# Dragon      2.666667
# Electric    0.855556
# Fairy       0.950000
# Fighting    1.185714
# Fire        1.216667
# Ghost       1.466667
# Grass       1.083333
# Ground      0.850000
# Ice         1.550000
# Normal      0.986364
# Poison      1.221429
# Psychic     1.371429
# Rock        1.844444
# Water       1.300000
# Name: Height, dtype: float64

# %%
df = pd.read_csv('dat.csv')
df
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
df.drop(columns=['Legendary'])
# Out:
#       No        Name    Type1   Type2  Height  Weight
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9
# 1      2     Ivysaur    Grass  Poison     1.0    13.0
# 2      3    Venusaur    Grass  Poison     2.0   100.0
# 3      4  Charmander     Fire     NaN     0.6     8.5
# 4      5  Charmeleon     Fire     NaN     1.1    19.0
# ..   ...         ...      ...     ...     ...     ...
# 145  146     Moltres     Fire  Flying     2.0    60.0
# 146  147     Dratini   Dragon     NaN     1.8     3.3
# 147  148   Dragonair   Dragon     NaN     4.0    16.5
# 148  149   Dragonite   Dragon  Flying     2.2   210.0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0
#
# [150 rows x 6 columns]

# %%
df.dropna(subset=['Type2'])
# Out:
#       No        Name     Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass  Poison     1.0    13.0          0
# 2      3    Venusaur     Grass  Poison     2.0   100.0          0
# 5      6   Charizard      Fire  Flying     1.7    90.5          0
# 11    12  Butterfree       Bug  Flying     1.1    32.0          0
# ..   ...         ...       ...     ...     ...     ...        ...
# 141  142  Aerodactyl      Rock  Flying     1.8    59.0          0
# 143  144    Articuno       Ice  Flying     1.7    55.4          1
# 144  145      Zapdos  Electric  Flying     1.6    52.6          1
# 145  146     Moltres      Fire  Flying     2.0    60.0          1
# 148  149   Dragonite    Dragon  Flying     2.2   210.0          0
#
# [67 rows x 7 columns]

# %%
df.fillna({'Type2': 'None'})
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire    None     0.6     8.5          0
# 4      5  Charmeleon     Fire    None     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon    None     1.8     3.3          0
# 147  148   Dragonair   Dragon    None     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
df['Type1'].replace({'Grass': 'GRASS'})
# Out:
# 0        GRASS
# 1        GRASS
# 2        GRASS
# 3         Fire
# 4         Fire
#         ...
# 145       Fire
# 146     Dragon
# 147     Dragon
# 148     Dragon
# 149    Psychic
# Name: Type1, Length: 150, dtype: object

# %%
df['Type1'].replace({'Fire': "FIRE"})
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3         FIRE
# 4         FIRE
#         ...
# 145       FIRE
# 146     Dragon
# 147     Dragon
# 148     Dragon
# 149    Psychic
# Name: Type1, Length: 150, dtype: object

# %%
df['Type1'].replace({'Fire': 'FUIre',
                    'Grass':'Gerass'},
                   )
# Out:
# 0       Gerass
# 1       Gerass
# 2       Gerass
# 3        FUIre
# 4        FUIre
#         ...
# 145      FUIre
# 146     Dragon
# 147     Dragon
# 148     Dragon
# 149    Psychic
# Name: Type1, Length: 150, dtype: object

# %%
df['Name'].str.lower()
# Out:
# 0       bulbasaur
# 1         ivysaur
# 2        venusaur
# 3      charmander
# 4      charmeleon
#           ...
# 145       moltres
# 146       dratini
# 147     dragonair
# 148     dragonite
# 149        mewtwo
# Name: Name, Length: 150, dtype: object

# %%
df['Type1'].str.upper()
# Out:
# 0        GRASS
# 1        GRASS
# 2        GRASS
# 3         FIRE
# 4         FIRE
#         ...
# 145       FIRE
# 146     DRAGON
# 147     DRAGON
# 148     DRAGON
# 149    PSYCHIC
# Name: Type1, Length: 150, dtype: object

# %%
df['Legendary'].astype(bool)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147    False
# 148    False
# 149     True
# Name: Legendary, Length: 150, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]
