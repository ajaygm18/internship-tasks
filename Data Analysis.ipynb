# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv('transaction_data.csv')

# %%
df.describe()
# Out:
#              UserId  TransactionId      ItemCode  NumberOfItemsPurchased  \
# count  1.083818e+06   1.083818e+06  1.083818e+06            1.083818e+06
# mean   2.410162e+05   6.159417e+06  6.582687e+05            2.865675e+01
# std    1.423364e+05   1.476341e+05  4.526314e+05            6.542432e+02
# min   -1.000000e+00   5.900015e+06 -1.000000e+00           -2.429850e+05
# 25%    2.593920e+05   6.026856e+06  4.609080e+05            3.000000e+00
# 50%    3.020220e+05   6.166611e+06  4.752930e+05            9.000000e+00
# 75%    3.413550e+05   6.289569e+06  4.889430e+05            3.000000e+01
# max    3.840270e+05   6.397457e+06  1.894494e+06            2.429850e+05
#
#         CostPerItem
# count  1.083818e+06
# mean   9.498798e+00
# std    2.308139e+03
# min   -1.526564e+04
# 25%    1.730000e+00
# 50%    2.880000e+00
# 75%    5.700000e+00
# max    1.696285e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083818 entries, 0 to 1083817
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1083818 non-null  int64
#  1   TransactionId           1083818 non-null  int64
#  2   TransactionTime         1083818 non-null  object
#  3   ItemCode                1083818 non-null  int64
#  4   ItemDescription         1080910 non-null  object
#  5   NumberOfItemsPurchased  1083818 non-null  int64
#  6   CostPerItem             1083818 non-null  float64
#  7   Country                 1083818 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 66.2+ MB

# %%
df.columns
# Out:
# Index(['UserId', 'TransactionId', 'TransactionTime', 'ItemCode',
#        'ItemDescription', 'NumberOfItemsPurchased', 'CostPerItem', 'Country'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# UserId   TransactionId  TransactionTime               ItemCode  ItemDescription                      NumberOfItemsPurchased  CostPerItem  Country
#  355383  6110764        Fri Aug 17 07:37:00 IST 2018  476658    PINK REGENCY TEACUP AND SAUCER       3                       4.08         United Kingdom    40
#                                                       476637    GREEN REGENCY TEACUP AND SAUCER      3                       4.08         United Kingdom    24
#  296142  6301471        Mon Jan 07 08:46:00 IST 2019  478275    PURPLE DRAWERKNOB ACRYLIC EDWARDIAN  36                      1.73         United Kingdom    16
#  329133  5953926        Fri Mar 30 12:25:00 IST 2018  456855    LOVE BUILDING BLOCK WORD             3                       8.22         United Kingdom    12
#  351435  5945764        Fri Mar 23 08:53:00 IST 2018  456876    BATH BUILDING BLOCK WORD             3                       8.22         United Kingdom    12
# ...

# %%
df.shape
# Out:
# (1083818, 8)

# %%
df.size
# Out:
# 8670544

# %%
df.ndim
# Out:
# 2

# %%
df.info
# Out:
# <bound method DataFrame.info of          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...         ...            ...                           ...       ...
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                            ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
df.dtypes
# Out:
# UserId                      int64
# TransactionId               int64
# TransactionTime            object
# ItemCode                    int64
# ItemDescription            object
# NumberOfItemsPurchased      int64
# CostPerItem               float64
# Country                    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# UserId                       0
# TransactionId                0
# TransactionTime              0
# ItemCode                     0
# ItemDescription           2908
# NumberOfItemsPurchased       0
# CostPerItem                  0
# Country                      0
# dtype: int64

# %%
df.head()
# Out:
#    UserId  TransactionId               TransactionTime  ItemCode  \
# 0  278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1  337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2  267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3  380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4      -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2          France
# 3  United Kingdom
# 4  United Kingdom

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...         ...            ...                           ...       ...
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                            ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
df.shape
# Out:
# (1080910, 8)

# %%
df.drop(columns=['UserId'])
# Out:
#          TransactionId               TransactionTime  ItemCode  \
# 0              6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1              6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2              6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3              6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4              6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...                ...                           ...       ...
# 1083813        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                            ItemDescription  NumberOfItemsPurchased  \
# 0         FAMILY ALBUM WHITE PICTURE FRAME                       6
# 1                    LONDON BUS COFFEE MUG                       3
# ...

# %%
df['ItemDescription'].str.split().str[-1]
# Out:
# 0              FRAME
# 1                MUG
# 2               GIRL
# 3                TAG
# 4               SIGN
#              ...
# 1083813    BUTTERFLY
# 1083814         PINK
# 1083815         CARD
# 1083816         TIER
# 1083817        SMALL
# Name: ItemDescription, Length: 1080910, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(545792)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (535118, 8)

# %%
df.dtypes
# Out:
# UserId                      int64
# TransactionId               int64
# TransactionTime            object
# ItemCode                    int64
# ItemDescription            object
# NumberOfItemsPurchased      int64
# CostPerItem               float64
# Country                    object
# dtype: object

# %%
df['TransactionTime'] = df['TransactionTime'].str.replace('IST', "")

# %%
df['TransactionTime'] = pd.to_datetime(df['TransactionTime'])

# %%
df['TransactionTime'].dt.date
# Out:
# 0          2019-02-02
# 1          2018-12-26
# 2          2019-02-15
# 3          2018-06-22
# 4          2018-09-10
#               ...
# 1080730    2019-01-28
# 1081224    2018-12-18
# 1081271    2018-12-23
# 1081376    2018-04-16
# 1081501    2018-07-31
# Name: TransactionTime, Length: 535118, dtype: object

# %%
df['TransactionDate'] = df['TransactionTime'].dt.date

# %%
df
# Out:
#          UserId  TransactionId     TransactionTime  ItemCode  \
# 0        278166        6355745 2019-02-02 12:50:00    465549
# 1        337701        6283376 2018-12-26 09:06:00    482370
# 2        267099        6385599 2019-02-15 09:45:00    490728
# 3        380478        6044973 2018-06-22 07:14:00    459186
# 4            -1        6143225 2018-09-10 11:58:00   1733592
# ...         ...            ...                 ...       ...
# 1080730      -1        6345240 2019-01-28 11:23:00    487116
# 1081224  342636        6268328 2018-12-18 09:48:00    481761
# 1081271  374577        6277348 2018-12-23 10:34:00    478506
# 1081376  378861        5973099 2018-04-16 09:11:00    469707
# 1081501      -1        6091437 2018-07-31 06:46:00    470631
#
#                            ItemDescription  NumberOfItemsPurchased  \
# 0         FAMILY ALBUM WHITE PICTURE FRAME                       6
# 1                    LONDON BUS COFFEE MUG                       3
# ...

# %%
df.groupby('TransactionDate')['UserId'].value_counts()
# Out:
# TransactionDate  UserId
# 2018-02-12       -1         1128
#                   374850      84
#                   377328      81
#                   261093      73
#                   309309      71
#                             ...
# 2028-02-18        317100       1
#                   325458       1
#                   328629       1
#                   369936       1
#                   372120       1
# Name: count, Length: 19571, dtype: int64

# %%
df['UserId'].nunique()
# Out:
# 4373

# %%
user_count_by_date = df.groupby('TransactionDate')['UserId'].nunique()

# %%
user_count_by_date = user_count_by_date.reset_index()

# %%
user_count_by_date
# Out:
#     TransactionDate  UserId
# 0        2018-02-12      99
# 1        2018-02-13     118
# 2        2018-02-14      56
# 3        2018-02-16      77
# 4        2018-02-17      91
# ..              ...     ...
# 300      2019-02-17     129
# 301      2019-02-18     102
# 302      2019-02-19     121
# 303      2019-02-20      39
# 304      2028-02-18      71
#
# [305 rows x 2 columns]

# %%
user_count_by_date = user_count_by_date.rename(columns={'UserId': 'UniqueUserId'})

# %%
user_count_by_date
# Out:
#     TransactionDate  UniqueUserId
# 0        2018-02-12            99
# 1        2018-02-13           118
# 2        2018-02-14            56
# 3        2018-02-16            77
# 4        2018-02-17            91
# ..              ...           ...
# 300      2019-02-17           129
# 301      2019-02-18           102
# 302      2019-02-19           121
# 303      2019-02-20            39
# 304      2028-02-18            71
#
# [305 rows x 2 columns]

# %%
df['TransactionDate'].value_counts().sort_values(ascending=False)
# Out:
# TransactionDate
# 2019-02-16    5290
# 2019-02-19    4905
# 2019-02-10    4235
# 2019-01-28    4127
# 2019-01-23    4035
#               ...
# 2018-05-25     525
# 2018-03-02     502
# 2018-07-13     450
# 2018-03-05     290
# 2018-04-20     273
# Name: count, Length: 305, dtype: int64

# %%
user_count_by_date['TransactionWeekday'] = user_count_by_date['TransactionDate'].apply(lambda x: x.weekday())

# %%
user_count_by_date
# Out:
#     TransactionDate  UniqueUserId  TransactionWeekday
# 0        2018-02-12            99                   0
# 1        2018-02-13           118                   1
# 2        2018-02-14            56                   2
# 3        2018-02-16            77                   4
# 4        2018-02-17            91                   5
# ..              ...           ...                 ...
# 300      2019-02-17           129                   6
# 301      2019-02-18           102                   0
# 302      2019-02-19           121                   1
# 303      2019-02-20            39                   2
# 304      2028-02-18            71                   4
#
# [305 rows x 3 columns]

# %%
user_count_by_date.groupby('TransactionWeekday')['UniqueUserId'].sum().sort_values(ascending=False)
# Conclusion obtained is that most transactions have happened on Sundays
# Out:
# TransactionWeekday
# 1    4411
# 0    3607
# 6    3387
# 5    3049
# 2    2963
# 4    2154
# Name: UniqueUserId, dtype: int64

# %%
df
# Out:
#          UserId  TransactionId     TransactionTime  ItemCode  \
# 0        278166        6355745 2019-02-02 12:50:00    465549
# 1        337701        6283376 2018-12-26 09:06:00    482370
# 2        267099        6385599 2019-02-15 09:45:00    490728
# 3        380478        6044973 2018-06-22 07:14:00    459186
# 4            -1        6143225 2018-09-10 11:58:00   1733592
# ...         ...            ...                 ...       ...
# 1080730      -1        6345240 2019-01-28 11:23:00    487116
# 1081224  342636        6268328 2018-12-18 09:48:00    481761
# 1081271  374577        6277348 2018-12-23 10:34:00    478506
# 1081376  378861        5973099 2018-04-16 09:11:00    469707
# 1081501      -1        6091437 2018-07-31 06:46:00    470631
#
#                            ItemDescription  NumberOfItemsPurchased  \
# 0         FAMILY ALBUM WHITE PICTURE FRAME                       6
# 1                    LONDON BUS COFFEE MUG                       3
# ...

# %%
transactions_count = df.groupby(['TransactionDate', 'UserId'])['ItemCode'].count().reset_index()

# %%
df.groupby(['TransactionDate', 'UserId'])['ItemCode'].value_counts().reset_index()
# Out:
#        TransactionDate  UserId  ItemCode  count
# 0           2018-02-12      -1    357252     12
# 1           2018-02-12      -1   1894494      9
# 2           2018-02-12      -1   1786029      6
# 3           2018-02-12      -1    999411      4
# 4           2018-02-12      -1   1528947      4
# ...                ...     ...       ...    ...
# 482136      2028-02-18  380499    479136      1
# 482137      2028-02-18  380499    479178      1
# 482138      2028-02-18  380499    481740      1
# 482139      2028-02-18  380499    481803      1
# 482140      2028-02-18  380499   1893738      1
#
# [482141 rows x 4 columns]

# %%
transactions_count
# Out:
#       TransactionDate  UserId  ItemCode
# 0          2018-02-12      -1      1128
# 1          2018-02-12  261051        14
# 2          2018-02-12  261093        73
# 3          2018-02-12  261912        14
# 4          2018-02-12  264243        20
# ...               ...     ...       ...
# 19566      2028-02-18  375837        34
# 19567      2028-02-18  377034         2
# 19568      2028-02-18  379155        28
# 19569      2028-02-18  380142        17
# 19570      2028-02-18  380499        29
#
# [19571 rows x 3 columns]

# %%
transactions_count.groupby(['TransactionDate'])['ItemCode'].idxmax()
# Out:
# TransactionDate
# 2018-02-12        0
# 2018-02-13      207
# 2018-02-14      217
# 2018-02-16      279
# 2018-02-17      350
#               ...
# 2019-02-17    19109
# 2019-02-18    19238
# 2019-02-19    19340
# 2019-02-20    19461
# 2028-02-18    19500
# Name: ItemCode, Length: 305, dtype: int64

# %%
max_transactions_by_date = transactions_count.iloc[transactions_count.groupby(['TransactionDate'])['ItemCode'].idxmax()]

# %%
transactions_count.iloc[transactions_count.groupby(['TransactionDate'])['ItemCode'].idxmax()]
# Out:
#       TransactionDate  UserId  ItemCode
# 0          2018-02-12      -1      1128
# 207        2018-02-13  374850       213
# 217        2018-02-14      -1      1055
# 279        2018-02-16  267708       185
# 350        2018-02-17      -1      1893
# ...               ...     ...       ...
# 19109      2019-02-17      -1       710
# 19238      2019-02-18      -1       237
# 19340      2019-02-19      -1      2339
# 19461      2019-02-20      -1      1008
# 19500      2028-02-18      -1      1821
#
# [305 rows x 3 columns]

# %%
transactions_count.rename(columns={'ItemCode':'ItemCount'}, inplace=True)

# %%
transactions_count
# Out:
#       TransactionDate  UserId  ItemCount
# 0          2018-02-12      -1       1128
# 1          2018-02-12  261051         14
# 2          2018-02-12  261093         73
# 3          2018-02-12  261912         14
# 4          2018-02-12  264243         20
# ...               ...     ...        ...
# 19566      2028-02-18  375837         34
# 19567      2028-02-18  377034          2
# 19568      2028-02-18  379155         28
# 19569      2028-02-18  380142         17
# 19570      2028-02-18  380499         29
#
# [19571 rows x 3 columns]

# %%
transactions_count.sort_values(by=['ItemCount'], ascending=False)
# Out:
#       TransactionDate  UserId  ItemCount
# 12094      2018-11-11      -1       2827
# 1147       2018-02-28      -1       2383
# 19340      2019-02-19      -1       2339
# 18994      2019-02-16      -1       1931
# 350        2018-02-17      -1       1893
# ...               ...     ...        ...
# 4294       2018-05-29  274953          1
# 4290       2018-05-29  271404          1
# 4289       2018-05-29  269745          1
# 19564      2028-02-18  372120          1
# 2810       2018-04-23  332367          1
#
# [19571 rows x 3 columns]

# %%
transactions_count.groupby('TransactionDate')['ItemCount'].sum().sort_values(ascending=False)
# Out:
# TransactionDate
# 2019-02-16    5290
# 2019-02-19    4905
# 2019-02-10    4235
# 2019-01-28    4127
# 2019-01-23    4035
#               ...
# 2018-05-25     525
# 2018-03-02     502
# 2018-07-13     450
# 2018-03-05     290
# 2018-04-20     273
# Name: ItemCount, Length: 305, dtype: int64

# %%
transactions_count.groupby('UserId')['ItemCount'].sum().sort_values(ascending=False)
# Out:
# UserId
# -1         133549
#  374661      7810
#  313131      5898
#  296016      5128
#  267708      4459
#             ...
#  321636         1
#  287763         1
#  359142         1
#  326004         1
#  381864         1
# Name: ItemCount, Length: 4373, dtype: int64

# %%
transactions_count.sort_values(by=['ItemCount'], ascending=False).loc[transactions_count['UserId'] != -1].head(5)
# Out:
#       TransactionDate  UserId  ItemCount
# 17117      2019-01-26  296016        543
# 18376      2019-02-09  296016        534
# 19026      2019-02-16  296016        530
# 18031      2019-02-04  296016        443
# 15952      2019-01-12  296016        436

# %%
df.groupby(['UserId'])['NumberOfItemsPurchased'].sum().sort_values(ascending=False).head(10).reset_index()
# Out:
#    UserId  NumberOfItemsPurchased
# 0      -1                  849621
# 1  307566                  590157
# 2  260715                  231726
# 3  313131                  231465
# 4  366450                  207027
# 5  380142                  192366
# 6  367731                  189036
# 7  287574                  185697
# 8  300258                  173883
# 9  297276                  170724

# %%
df[['UserId', 'TransactionId', 'ItemCode', 'NumberOfItemsPurchased']].describe().astype(int)
# Out:
#        UserId  TransactionId  ItemCode  NumberOfItemsPurchased
# count  535118         535118    535118                  535118
# mean   240816        6159311    657636                      29
# std    142333         147531    452082                     657
# min        -1        5900015        -1                 -242985
# 25%    259329        6026856    460929                       3
# 50%    301560        6166490    475293                       9
# 75%    341082        6288975    488901                      30
# max    384027        6397457   1894494                  242985

# %%
df[['UserId', 'TransactionId', 'ItemCode', 'NumberOfItemsPurchased']].nunique()
# Out:
# UserId                     4373
# TransactionId             24446
# ItemCode                   3321
# NumberOfItemsPurchased      671
# dtype: int64

# %%
df['NumberOfItemsPurchased'].min()
# Out:
# np.int64(-242985)

# %%
df['UserId'].value_counts().reset_index().sort_values(by='count', ascending=False)[1:].head(10).reset_index(drop=True)
# Out:
#    UserId  count
# 0  374661   7810
# 1  313131   5898
# 2  296016   5128
# 3  267708   4459
# 4  306726   2759
# 5  321531   2478
# 6  307566   2085
# 7  274869   1853
# 8  278523   1667
# 9  300258   1638

# %%
countries_top10 = df.groupby('Country')['TransactionId'].nunique().sort_values(ascending=False).head(10)

# %%
df
# Out:
#          UserId  TransactionId     TransactionTime  ItemCode  \
# 0        278166        6355745 2019-02-02 12:50:00    465549
# 1        337701        6283376 2018-12-26 09:06:00    482370
# 2        267099        6385599 2019-02-15 09:45:00    490728
# 3        380478        6044973 2018-06-22 07:14:00    459186
# 4            -1        6143225 2018-09-10 11:58:00   1733592
# ...         ...            ...                 ...       ...
# 1080730      -1        6345240 2019-01-28 11:23:00    487116
# 1081224  342636        6268328 2018-12-18 09:48:00    481761
# 1081271  374577        6277348 2018-12-23 10:34:00    478506
# 1081376  378861        5973099 2018-04-16 09:11:00    469707
# 1081501      -1        6091437 2018-07-31 06:46:00    470631
#
#                            ItemDescription  NumberOfItemsPurchased  \
# 0         FAMILY ALBUM WHITE PICTURE FRAME                       6
# 1                    LONDON BUS COFFEE MUG                       3
# ...

# %%
countries_top10
# Out:
# Country
# United Kingdom    22040
# Germany             603
# France              461
# EIRE                360
# Belgium             119
# Spain               105
# Netherlands         101
# Switzerland          74
# Portugal             71
# Australia            69
# Name: TransactionId, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.ylabel("Transaction Counts")
plt.title("Country wise Transactions")
countries_top10.plot(kind='bar', color='skyblue', edgecolor='black')
plt.tight_layout()
plt.show()

# %%
countries_transactions = df.groupby('Country')['TransactionId'].nunique().sort_values(ascending=False).reset_index()

# %%
countries_transactions.head(10)
# Out:
#           Country  TransactionId
# 0  United Kingdom          22040
# 1         Germany            603
# 2          France            461
# 3            EIRE            360
# 4         Belgium            119
# 5           Spain            105
# 6     Netherlands            101
# 7     Switzerland             74
# 8        Portugal             71
# 9       Australia             69

# %%
countries_transactions.columns = ['Country', 'UniqueTransactions']

# %%
countries_transactions
# Out:
#                  Country  UniqueTransactions
# 0         United Kingdom               22040
# 1                Germany                 603
# 2                 France                 461
# 3                   EIRE                 360
# 4                Belgium                 119
# 5                  Spain                 105
# 6            Netherlands                 101
# 7            Switzerland                  74
# 8               Portugal                  71
# 9              Australia                  69
# 10                 Italy                  55
# 11               Finland                  48
# 12                Sweden                  46
# 13                Norway                  40
# 14       Channel Islands                  33
# 15                 Japan                  28
# 16                Poland                  24
# 17               Denmark                  21
# 18                Cyprus                  20
# 19               Austria                  19
# ...

# %%
plt.figure(figsize=(12, 6))
plt.title('Country Wise Transactions', fontsize=10)
sns.barplot(data=countries_transactions.head(10), x='Country', y='UniqueTransactions')
plt.tight_layout()
plt.show()

# %%
df['NumberOfItemsPurchased'].describe()
# Out:
# count    535118.000000
# mean         29.016845
# std         657.219445
# min     -242985.000000
# 25%           3.000000
# 50%           9.000000
# 75%          30.000000
# max      242985.000000
# Name: NumberOfItemsPurchased, dtype: float64

# %%
filtered_df = df['NumberOfItemsPurchased'].loc[(df['NumberOfItemsPurchased'] > 0) & (df['NumberOfItemsPurchased'] < 50)].reset_index(drop=True)
filtered_df
# Out:
# 0          6
# 1          3
# 2          3
# 3          3
# 4         12
#           ..
# 461320     3
# 461321    24
# 461322     9
# 461323    12
# 461324    15
# Name: NumberOfItemsPurchased, Length: 461325, dtype: int64

# %%
plt.figure(figsize=(6,10))
plt.hist(filtered_df, bins=10, edgecolor="black", color='skyblue')
plt.title("Histogram of No of Items Purchased")
plt.xlabel("No of Items Purchased")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=filtered_df, bins=30)
# Out:
# <Axes: xlabel='NumberOfItemsPurchased', ylabel='Count'>

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

# %%
filtered_trans = df.loc[df['TransactionDate'] < pd.to_datetime('2020-02-02')]
filtered_trans
# Out:
#          UserId  TransactionId     TransactionTime  ItemCode  \
# 0        278166        6355745 2019-02-02 12:50:00    465549
# 1        337701        6283376 2018-12-26 09:06:00    482370
# 2        267099        6385599 2019-02-15 09:45:00    490728
# 3        380478        6044973 2018-06-22 07:14:00    459186
# 4            -1        6143225 2018-09-10 11:58:00   1733592
# ...         ...            ...                 ...       ...
# 1080730      -1        6345240 2019-01-28 11:23:00    487116
# 1081224  342636        6268328 2018-12-18 09:48:00    481761
# 1081271  374577        6277348 2018-12-23 10:34:00    478506
# 1081376  378861        5973099 2018-04-16 09:11:00    469707
# 1081501      -1        6091437 2018-07-31 06:46:00    470631
#
#                            ItemDescription  NumberOfItemsPurchased  \
# 0         FAMILY ALBUM WHITE PICTURE FRAME                       6
# 1                    LONDON BUS COFFEE MUG                       3
# ...

# %%
transactions = filtered_trans.groupby('TransactionDate')['TransactionId'].nunique().sort_index(ascending=True)
transactions
# Out:
# TransactionDate
# 2018-02-12    133
# 2018-02-13    165
# 2018-02-14     78
# 2018-02-16     95
# 2018-02-17    123
#              ...
# 2019-02-16    149
# 2019-02-17    148
# 2019-02-18    133
# 2019-02-19    143
# 2019-02-20     49
# Name: TransactionId, Length: 304, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.plot(transactions.index, transactions.values, marker='o', linestyle='dotted')
plt.title("Number of transactions date wise")
plt.xlabel("Date")
plt.ylabel("Number of transactions")
plt.show()

# %%
sns.lineplot(x=transactions.index, y=transactions.values)
# Out:
# <Axes: xlabel='TransactionDate'>

# %%
filtered = df.loc[(df['NumberOfItemsPurchased'] > 0) & (df['CostPerItem'] > 0)]
filtered = filtered.loc[(filtered['NumberOfItemsPurchased'] < 500) & (filtered['CostPerItem'] <  50)]

# %%
filtered['CostPerItem'].describe().astype(int)
# Out:
# count    520754
# mean          4
# std           4
# min           0
# 25%           1
# 50%           2
# 75%           5
# max          49
# Name: CostPerItem, dtype: int64

# %%
plt.figure(figsize=(6,10))
plt.scatter(filtered['CostPerItem'], filtered['NumberOfItemsPurchased'])
plt.xlabel("Cost per Item")
plt.ylabel("Quantity of Products")
plt.title("Cost per item vs Number of Products")
plt.show()

# %%
sns.scatterplot(data=filtered, x='CostPerItem', y='NumberOfItemsPurchased', alpha=0.3, size='CostPerItem')
# Out:
# <Axes: xlabel='CostPerItem', ylabel='NumberOfItemsPurchased'>

# %%
corr_matrix = filtered[['NumberOfItemsPurchased', 'CostPerItem']].corr(numeric_only=True)

# %%
plt.title('Corr Matrix')
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: title={'center': 'Corr Matrix'}>

# %%
top_countries = df['Country'].value_counts()
top_countries
# Out:
# Country
# United Kingdom          488779
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     610
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     293
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
top_country = df.groupby('Country')['TransactionId'].nunique().sort_values(ascending=False).head(10)
top_country.index
# Out:
# Index(['United Kingdom', 'Germany', 'France', 'EIRE', 'Belgium', 'Spain',
#        'Netherlands', 'Switzerland', 'Portugal', 'Australia'],
#       dtype='object', name='Country')

# %%
top = df[df['Country'].isin(top_country.index)]

# %%
filtered = top.loc[(top['NumberOfItemsPurchased'] > 0) & (top['CostPerItem'] > 0)]
filtered = filtered.loc[(filtered['NumberOfItemsPurchased'] < 500) & (filtered['CostPerItem'] <  50)]

# %%
plt.xticks(rotation=45)
plt.title("Country wise costs")
sns.boxplot(data=filtered, x='Country', y='CostPerItem')
# Out:
# <Axes: title={'center': 'Country wise costs'}, xlabel='Country', ylabel='CostPerItem'>

# %%
df.groupby('ItemDescription')['NumberOfItemsPurchased']

# %%
filtered = df[df['NumberOfItemsPurchased'] > 0]
filtered = filtered.groupby('ItemDescription')['NumberOfItemsPurchased'].sum().sort_values(ascending=False).head(5)
filtered
# Out:
# ItemDescription
# PAPER CRAFT , LITTLE BIRDIE           242985
# MEDIUM CERAMIC TOP STORAGE JAR        234099
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     164853
# JUMBO BAG RED RETROSPOT               145125
# WHITE HANGING HEART T-LIGHT HOLDER    113628
# Name: NumberOfItemsPurchased, dtype: int64

# %%
sns.barplot(y=filtered.index, x=filtered.values)
plt.title("Top 5 selling items")
# Out:
# Text(0.5, 1.0, 'Top 5 selling items')

# %%
filtered = df[(df['NumberOfItemsPurchased'] < 50) & (df['NumberOfItemsPurchased'] > 0) & (df['CostPerItem'] < 100) & (df['CostPerItem'] > 0)]

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.histplot(data=filtered, x='NumberOfItemsPurchased', bins=30, ax=axes[0])
sns.scatterplot(data=filtered, x='CostPerItem', y='NumberOfItemsPurchased', ax=axes[1], alpha=0.3)
axes[0].set_title("Distribution of Quantities")
axes[1].set_title("Price vs Quantity")
plt.tight_layout()
plt.show()

# %%
df.groupby(['Country', 'NumberOfItemsPurchased']).size()
# Out:
# Country      NumberOfItemsPurchased
# Australia    -360                       1
#              -300                       1
#              -258                       1
#              -108                       2
#              -72                        2
#                                        ..
# Unspecified   72                       31
#               75                       20
#               108                       3
#               120                       1
#               144                       3
# Length: 1803, dtype: int64
